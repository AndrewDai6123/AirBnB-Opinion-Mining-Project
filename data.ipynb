# %%
# import all packages needed
import pandas as pd
import os

# Data path 
DIR_PATH = os.getcwd() + '/data/'

LISTING_FIlE = DIR_PATH + "listings.csv"
LISTING2_FIlE = DIR_PATH + "listings2.csv"
REVIEWS_FILE = DIR_PATH + "reviews.csv"
REVIEWS2_FILE = DIR_PATH + "reviews2.csv"
NEIGHBOURHOOD_FILE = DIR_PATH + "neighbourhoods.csv"

# %% [markdown]
# Open the data files needed for the Air BnB project

# %%
# Open all the data files and convert to a dataframe
def openFiles(file):
    # Convert to dataframe
    df = pd.read_csv(file, index_col=0)
    
    print("File opened successfuly")
    
    return df

# %%
listing_df = openFiles(LISTING_FIlE)
# Out:
# File opened successfuly

# %%
reviews2_df = openFiles(REVIEWS2_FILE)
# Out:
# File opened successfuly

# %%
listing2_df = openFiles(LISTING2_FIlE)
# Out:
# File opened successfuly
# C:\Users\andre\AppData\Local\Temp\ipykernel_16388\823213661.py:4: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, index_col=0)

# %%
reviews_df = openFiles(REVIEWS_FILE)
# Out:
# File opened successfuly

# %%
neighborhood_df = openFiles(NEIGHBOURHOOD_FILE)
# Out:
# File opened successfuly

# %%
listing_df
# Out:
#                                                                  name  \
# id
# 77765                                            Superior @ Box House
# 2539                               Clean & quiet apt home by the park
# 45910                              Beautiful Queens Brownstone! - 5BR
# 45935                                    Room in Beautiful Townhouse.
# 45936                              Couldn't Be Closer To Columbia Uni
# ...                                                               ...
# 27577588                     Luxury Studio ON Grove Street E0C - B1CA
# 654151117629853651                        Lovely 3- bedroom apartment
# 553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 48971505                     Just Blocks to Grove PATH and JC Med Ctr
#
#                       host_id            host_name neighbourhood_group  \
# id
# 77765                  417504  The Box House Hotel            Brooklyn
# 2539                     2787                 John            Brooklyn
# 45910                  204539                 Mark              Queens
# 45935                  204586                    L               Bronx
# 45936                  867225                Rahul           Manhattan
# ...                       ...                  ...                 ...
# 27577588             37412692                  Kim           Manhattan
# 654151117629853651  117540494               Miriam              Queens
# 553754115911961053   15048320                India           Manhattan
# 698195550745703156  151487807                Asser            Brooklyn
# 48971505                46201                    J           Manhattan
#
#                           neighbourhood   latitude  longitude  \
# id
# 77765                        Greenpoint  40.737770 -73.953660
# 2539                         Kensington  40.645290 -73.972380
# 45910                         Ridgewood  40.703090 -73.899630
# 45935                        Mott Haven  40.806350 -73.922010
# 45936               Morningside Heights  40.806300 -73.959850
# ...                                 ...        ...        ...
# 27577588                   Ellis Island  40.718220 -74.037940
# 654151117629853651             Rosedale  40.647244 -73.720088
# 553754115911961053      Upper West Side  40.787320 -74.004470
# 698195550745703156         Williamsburg  40.709192 -73.970121
# 48971505                   Ellis Island  40.718350 -74.044160
#
#                           room_type  price  minimum_nights  number_of_reviews  \
# id
# 77765                    Hotel room    308               2                 42
# 2539                   Private room    299              30                  9
# 45910               Entire home/apt    425              30                 13
# 45935                  Private room     60              30                  0
# 45936                  Private room     75              31                135
# ...                             ...    ...             ...                ...
# 27577588            Entire home/apt    135             365                  2
# 654151117629853651  Entire home/apt    180               1                  5
# 553754115911961053  Entire home/apt    240               5                 18
# 698195550745703156  Entire home/apt    400              30                  0
# 48971505               Private room     40               1                 15
#
#                    last_review  reviews_per_month  \
# id
# 77765               2022-07-18               0.30
# 2539                2018-10-19               0.11
# 45910               2019-11-12               0.10
# 45935                      NaN                NaN
# 45936               2022-07-11               0.95
# ...                        ...                ...
# 27577588            2019-09-16               0.04
# 654151117629853651  2022-08-24               1.92
# 553754115911961053  2022-08-22               2.87
# 698195550745703156         NaN                NaN
# 48971505            2021-10-25               0.91
#
#                     calculated_host_listings_count  availability_365  \
# id
# 77765                                           30               217
# 2539                                             9               356
# 45910                                            6               365
# 45935                                            1                83
# 45936                                            1               219
# ...                                            ...               ...
# 27577588                                         7               365
# 654151117629853651                               1                 0
# 553754115911961053                               1               152
# 698195550745703156                               1               311
# 48971505                                         1                 0
#
#                     number_of_reviews_ltm license
# id
# 77765                                   4     NaN
# 2539                                    0     NaN
# 45910                                   0     NaN
# 45935                                   0     NaN
# 45936                                   4     NaN
# ...                                   ...     ...
# 27577588                                0     NaN
# 654151117629853651                      5     NaN
# 553754115911961053                     18     NaN
# 698195550745703156                      0     NaN
# 48971505                                4     NaN
#
# [39881 rows x 17 columns]

# %%
listing_df = listing_df.drop('license', axis=1)

# %%
listing_df = listing_df.drop('availability_365', axis=1)

# %%
listing_df = listing_df.drop('calculated_host_listings_count', axis=1)

# %%
listing_df = listing_df.drop('minimum_nights', axis=1)

# %%
listing_df = listing_df.drop('price', axis=1)

# %%
listing_df = listing_df.drop('reviews_per_month', axis=1)

# %%
listing_df
# Out:
#                                                                  name  \
# id
# 77765                                            Superior @ Box House
# 2539                               Clean & quiet apt home by the park
# 45910                              Beautiful Queens Brownstone! - 5BR
# 45935                                    Room in Beautiful Townhouse.
# 45936                              Couldn't Be Closer To Columbia Uni
# ...                                                               ...
# 27577588                     Luxury Studio ON Grove Street E0C - B1CA
# 654151117629853651                        Lovely 3- bedroom apartment
# 553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 48971505                     Just Blocks to Grove PATH and JC Med Ctr
#
#                       host_id            host_name neighbourhood_group  \
# id
# 77765                  417504  The Box House Hotel            Brooklyn
# 2539                     2787                 John            Brooklyn
# 45910                  204539                 Mark              Queens
# 45935                  204586                    L               Bronx
# 45936                  867225                Rahul           Manhattan
# ...                       ...                  ...                 ...
# 27577588             37412692                  Kim           Manhattan
# 654151117629853651  117540494               Miriam              Queens
# 553754115911961053   15048320                India           Manhattan
# 698195550745703156  151487807                Asser            Brooklyn
# 48971505                46201                    J           Manhattan
#
#                           neighbourhood   latitude  longitude  \
# id
# 77765                        Greenpoint  40.737770 -73.953660
# 2539                         Kensington  40.645290 -73.972380
# 45910                         Ridgewood  40.703090 -73.899630
# 45935                        Mott Haven  40.806350 -73.922010
# 45936               Morningside Heights  40.806300 -73.959850
# ...                                 ...        ...        ...
# 27577588                   Ellis Island  40.718220 -74.037940
# 654151117629853651             Rosedale  40.647244 -73.720088
# 553754115911961053      Upper West Side  40.787320 -74.004470
# 698195550745703156         Williamsburg  40.709192 -73.970121
# 48971505                   Ellis Island  40.718350 -74.044160
#
#                           room_type  number_of_reviews last_review  \
# id
# 77765                    Hotel room                 42  2022-07-18
# 2539                   Private room                  9  2018-10-19
# 45910               Entire home/apt                 13  2019-11-12
# 45935                  Private room                  0         NaN
# 45936                  Private room                135  2022-07-11
# ...                             ...                ...         ...
# 27577588            Entire home/apt                  2  2019-09-16
# 654151117629853651  Entire home/apt                  5  2022-08-24
# 553754115911961053  Entire home/apt                 18  2022-08-22
# 698195550745703156  Entire home/apt                  0         NaN
# 48971505               Private room                 15  2021-10-25
#
#                     number_of_reviews_ltm
# id
# 77765                                   4
# 2539                                    0
# 45910                                   0
# 45935                                   0
# 45936                                   4
# ...                                   ...
# 27577588                                0
# 654151117629853651                      5
# 553754115911961053                     18
# 698195550745703156                      0
# 48971505                                4
#
# [39881 rows x 11 columns]

# %%
listing2_df
# Out:
#                                                         listing_url  \
# id
# 2539                              https://www.airbnb.com/rooms/2539
# 2595                              https://www.airbnb.com/rooms/2595
# 5121                              https://www.airbnb.com/rooms/5121
# 45910                            https://www.airbnb.com/rooms/45910
# 5136                              https://www.airbnb.com/rooms/5136
# ...                                                             ...
# 43728504                      https://www.airbnb.com/rooms/43728504
# 44578886                      https://www.airbnb.com/rooms/44578886
# 46355090                      https://www.airbnb.com/rooms/46355090
# 698195550745703156  https://www.airbnb.com/rooms/698195550745703156
# 48971505                      https://www.airbnb.com/rooms/48971505
#
#                          scrape_id last_scraped           source  \
# id
# 2539                20220907064715   2022-09-07      city scrape
# 2595                20220907064715   2022-09-07      city scrape
# 5121                20220907064715   2022-09-07      city scrape
# 45910               20220907064715   2022-09-07      city scrape
# 5136                20220907064715   2022-09-07      city scrape
# ...                            ...          ...              ...
# 43728504            20220907064715   2022-09-08  previous scrape
# 44578886            20220907064715   2022-09-08  previous scrape
# 46355090            20220907064715   2022-09-08  previous scrape
# 698195550745703156  20220907064715   2022-09-08      city scrape
# 48971505            20220907064715   2022-09-08  previous scrape
#
#                                                                  name  \
# id
# 2539                               Clean & quiet apt home by the park
# 2595                                            Skylit Midtown Castle
# 5121                                                  BlissArtsSpace!
# 45910                              Beautiful Queens Brownstone! - 5BR
# 5136                         Spacious Brooklyn Duplex, Patio + Garden
# ...                                                               ...
# 43728504                            Private Modern House by The Beach
# 44578886                         Beautiful apartment - minutes to NYC
# 46355090                          1 Bedroom Basement, NEWLY Renovated
# 698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 48971505                     Just Blocks to Grove PATH and JC Med Ctr
#
#                                                           description  \
# id
# 2539                Renovated apt home in elevator building.<br />...
# 2595                Beautiful, spacious skylit studio in the heart...
# 5121                One room available for rent in a 2 bedroom apt...
# 45910               <b>The space</b><br />Beautiful, fully furnish...
# 5136                We welcome you to stay in our lovely 2 br dupl...
# ...                                                               ...
# 43728504            Private modern house by the Beach with all com...
# 44578886            Our apartment is straight across the river fro...
# 46355090            With easy access to multiple bus stops and the...
# 698195550745703156  This two bed, two bath apartment overlooking t...
# 48971505            Very convenient to the Grove St PATH (5 min wa...
#
#                                                 neighborhood_overview  \
# id
# 2539                  Close to Prospect Park and Historic Ditmas Park
# 2595                Centrally located in the heart of Manhattan ju...
# 5121                                                              NaN
# 45910                                                             NaN
# 5136                                                              NaN
# ...                                                               ...
# 43728504            Rockaway Beach is a neighborhood that gives it...
# 44578886            Our apartment is located in a very interesting...
# 46355090                                                          NaN
# 698195550745703156                                                NaN
# 48971505                                                          NaN
#
#                                                           picture_url  \
# id
# 2539                https://a0.muscache.com/pictures/3949d073-a02e...
# 2595                https://a0.muscache.com/pictures/f0813a11-40b2...
# 5121                https://a0.muscache.com/pictures/2090980c-b68e...
# 45910               https://a0.muscache.com/pictures/27117627/19ff...
# 5136                https://a0.muscache.com/pictures/miso/Hosting-...
# ...                                                               ...
# 43728504            https://a0.muscache.com/pictures/6c950656-b090...
# 44578886            https://a0.muscache.com/pictures/dd5163c1-7e02...
# 46355090            https://a0.muscache.com/pictures/64c81ee7-b396...
# 698195550745703156  https://a0.muscache.com/pictures/miso/Hosting-...
# 48971505            https://a0.muscache.com/pictures/b12bc7dc-573c...
#
#                       host_id                                     host_url  \
# id
# 2539                     2787       https://www.airbnb.com/users/show/2787
# 2595                     2845       https://www.airbnb.com/users/show/2845
# 5121                     7356       https://www.airbnb.com/users/show/7356
# 45910                  204539     https://www.airbnb.com/users/show/204539
# 5136                     7378       https://www.airbnb.com/users/show/7378
# ...                       ...                                          ...
# 43728504             23049030   https://www.airbnb.com/users/show/23049030
# 44578886             48009648   https://www.airbnb.com/users/show/48009648
# 46355090            371552251  https://www.airbnb.com/users/show/371552251
# 698195550745703156  151487807  https://www.airbnb.com/users/show/151487807
# 48971505                46201      https://www.airbnb.com/users/show/46201
#
#                     ... review_scores_communication review_scores_location  \
# id                  ...
# 2539                ...                        5.00                   4.75
# 2595                ...                        4.80                   4.81
# 5121                ...                        4.91                   4.47
# 45910               ...                        5.00                   4.82
# 5136                ...                        5.00                   4.67
# ...                 ...                         ...                    ...
# 43728504            ...                        5.00                   4.94
# 44578886            ...                        4.96                   4.81
# 46355090            ...                        4.36                   4.36
# 698195550745703156  ...                         NaN                    NaN
# 48971505            ...                        4.73                   4.87
#
#                    review_scores_value license instant_bookable  \
# id
# 2539                              4.88     NaN                f
# 2595                              4.40     NaN                f
# 5121                              4.52     NaN                f
# 45910                             4.55     NaN                f
# 5136                              5.00     NaN                f
# ...                                ...     ...              ...
# 43728504                          4.88     NaN                f
# 44578886                          4.85     NaN                f
# 46355090                          4.55     NaN                t
# 698195550745703156                 NaN     NaN                f
# 48971505                          4.47     NaN                f
#
#                    calculated_host_listings_count  \
# id
# 2539                                            9
# 2595                                            3
# 5121                                            2
# 45910                                           6
# 5136                                            1
# ...                                           ...
# 43728504                                        1
# 44578886                                        1
# 46355090                                        1
# 698195550745703156                              1
# 48971505                                        1
#
#                    calculated_host_listings_count_entire_homes  \
# id
# 2539                                                         1
# 2595                                                         3
# 5121                                                         0
# 45910                                                        6
# 5136                                                         1
# ...                                                        ...
# 43728504                                                     1
# 44578886                                                     1
# 46355090                                                     1
# 698195550745703156                                           1
# 48971505                                                     0
#
#                    calculated_host_listings_count_private_rooms  \
# id
# 2539                                                          6
# 2595                                                          0
# 5121                                                          2
# 45910                                                         0
# 5136                                                          0
# ...                                                         ...
# 43728504                                                      0
# 44578886                                                      0
# 46355090                                                      0
# 698195550745703156                                            0
# 48971505                                                      1
#
#                    calculated_host_listings_count_shared_rooms  \
# id
# 2539                                                         2
# 2595                                                         0
# 5121                                                         0
# 45910                                                        0
# 5136                                                         0
# ...                                                        ...
# 43728504                                                     0
# 44578886                                                     0
# 46355090                                                     0
# 698195550745703156                                           0
# 48971505                                                     0
#
#                    reviews_per_month
# id
# 2539                            0.11
# 2595                            0.31
# 5121                            0.31
# 45910                           0.10
# 5136                            0.03
# ...                              ...
# 43728504                        1.22
# 44578886                        2.12
# 46355090                        0.50
# 698195550745703156               NaN
# 48971505                        0.91
#
# [39881 rows x 74 columns]

# %%
neighborhood_df
# Out:
#                      neighbourhood
# neighbourhood_group
# Bronx                     Allerton
# Bronx                   Baychester
# Bronx                      Belmont
# Bronx                    Bronxdale
# Bronx                  Castle Hill
# ...                            ...
# Staten Island          Tottenville
# Staten Island        West Brighton
# Staten Island          Westerleigh
# Staten Island          Willowbrook
# Staten Island              Woodrow
#
# [230 rows x 1 columns]

# %%
reviews_df
# Out:
#                           date
# listing_id
# 2539                2015-12-04
# 2539                2016-08-27
# 2539                2016-10-01
# 2539                2017-02-20
# 2539                2017-03-19
# ...                        ...
# 705982958145847356  2022-09-05
# 706000708692803625  2022-09-04
# 706477762633031457  2022-09-05
# 706487852182826405  2022-09-03
# 707272556257060819  2022-09-05
#
# [1064458 rows x 1 columns]

# %% [markdown]
# Pre-processing Step:
# - Clean the data frame to the needed attributes we need
# - Fill in the missing values or remove the na values if no reviews are also in the reviews2 table

# %%
# Fill in the missing value for the following columns: last_review
# For the column last_review it lets us know when the last review was posted if no reviews were made then the value is NaN
listing_last_review_df = listing_df[["number_of_reviews", "last_review"]]

# %%
# show all the NaN values
listing_last_review_df[listing_last_review_df.isna().any(axis=1)]
# Out:
#                     number_of_reviews last_review
# id
# 45935                               0         NaN
# 51438                               0         NaN
# 54466                               0         NaN
# 11943                               0         NaN
# 113092                              0         NaN
# ...                               ...         ...
# 23185254                            0         NaN
# 629813073409916623                  0         NaN
# 637667152834352362                  0         NaN
# 670851597591736404                  0         NaN
# 698195550745703156                  0         NaN
#
# [8362 rows x 2 columns]

# %%
reviews2_df
# Out:
#                                     id        date  reviewer_id reviewer_name  \
# listing_id
# 2539                          55688172  2015-12-04     25160947         Peter
# 2539                          97474898  2016-08-27     91513326           Liz
# 2539                         105340344  2016-10-01     90022459       Евгений
# 2539                         133131670  2017-02-20    116165195        George
# 2539                         138349776  2017-03-19    118432644        Carlos
# ...                                ...         ...          ...           ...
# 706487852182826405  707994213814611994  2022-09-03    179206698          Eman
# 706611147133623424  707230144870147247  2022-09-02    339848823         David
# 706712410572332671  709394649699674170  2022-09-05     51119059           Caz
# 706752921121143414  709415974927452008  2022-09-05    456707191         Pablo
# 707272556257060819  709356358670109209  2022-09-05     62541346        Taunda
#
#                                                              comments
# listing_id
# 2539                                                      Great host
# 2539                Nice room for the price. Great neighborhood. J...
# 2539                                   Very nice apt.  New remodeled.
# 2539                Great place to stay for a while. John is a gre...
# 2539                                                                .
# ...                                                               ...
# 706487852182826405  Very tidy and lovely AirBnb studio equipped wi...
# 706611147133623424  The room is perfect for travelers like me who ...
# 706712410572332671  Loved staying here! It is a stunning place to ...
# 706752921121143414  We really enjoyed our stay in Alberto's place....
# 707272556257060819             What an amazing host!  Great location!
#
# [1064458 rows x 5 columns]

# %%
listing_df.dtypes
# Out:
# name                      object
# host_id                    int64
# host_name                 object
# neighbourhood_group       object
# neighbourhood             object
# latitude                 float64
# longitude                float64
# room_type                 object
# number_of_reviews          int64
# last_review               object
# number_of_reviews_ltm      int64
# dtype: object

# %%
reviews2_df.dtypes
# Out:
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
# check that in the listing_df table and reviews2_df table, if the listing has 0 reviews that is the same in the reviews2 table
# It does not exisit so we can drop all the rows with NaN values in listing_df
listing_df.dropna()
# Out:
#                                                             name    host_id  \
# id
# 77765                                       Superior @ Box House     417504
# 2539                          Clean & quiet apt home by the park       2787
# 45910                         Beautiful Queens Brownstone! - 5BR     204539
# 45936                         Couldn't Be Closer To Columbia Uni     867225
# 80493                          Cozy room in East Village with AC     434987
# ...                                                          ...        ...
# 628769808856889664  Two bedroom apartment in Hoboken New Jersey.   14468718
# 27577588                Luxury Studio ON Grove Street E0C - B1CA   37412692
# 654151117629853651                   Lovely 3- bedroom apartment  117540494
# 553754115911961053     Trendy 3-bedroom apartment near Manhattan   15048320
# 48971505                Just Blocks to Grove PATH and JC Med Ctr      46201
#
#                               host_name neighbourhood_group  \
# id
# 77765               The Box House Hotel            Brooklyn
# 2539                               John            Brooklyn
# 45910                              Mark              Queens
# 45936                             Rahul           Manhattan
# 80493                          Jennifer           Manhattan
# ...                                 ...                 ...
# 628769808856889664                Burak           Manhattan
# 27577588                            Kim           Manhattan
# 654151117629853651               Miriam              Queens
# 553754115911961053                India           Manhattan
# 48971505                              J           Manhattan
#
#                           neighbourhood   latitude  longitude  \
# id
# 77765                        Greenpoint  40.737770 -73.953660
# 2539                         Kensington  40.645290 -73.972380
# 45910                         Ridgewood  40.703090 -73.899630
# 45936               Morningside Heights  40.806300 -73.959850
# 80493                      East Village  40.723220 -73.986150
# ...                                 ...        ...        ...
# 628769808856889664         West Village  40.740227 -74.027504
# 27577588                   Ellis Island  40.718220 -74.037940
# 654151117629853651             Rosedale  40.647244 -73.720088
# 553754115911961053      Upper West Side  40.787320 -74.004470
# 48971505                   Ellis Island  40.718350 -74.044160
#
#                           room_type  number_of_reviews last_review  \
# id
# 77765                    Hotel room                 42  2022-07-18
# 2539                   Private room                  9  2018-10-19
# 45910               Entire home/apt                 13  2019-11-12
# 45936                  Private room                135  2022-07-11
# 80493                  Private room                207  2022-08-13
# ...                             ...                ...         ...
# 628769808856889664  Entire home/apt                  2  2022-07-29
# 27577588            Entire home/apt                  2  2019-09-16
# 654151117629853651  Entire home/apt                  5  2022-08-24
# 553754115911961053  Entire home/apt                 18  2022-08-22
# 48971505               Private room                 15  2021-10-25
#
#                     number_of_reviews_ltm
# id
# 77765                                   4
# 2539                                    0
# 45910                                   0
# 45936                                   4
# 80493                                   9
# ...                                   ...
# 628769808856889664                      2
# 27577588                                0
# 654151117629853651                      5
# 553754115911961053                     18
# 48971505                                4
#
# [31505 rows x 11 columns]
